# %% [markdown]
# ## 循环神经网络的工作过程
#
# 循环神经网络是一个处理时间序列数据的神经网络结构，也就是说，我们需要在脑海里有一根时间轴，循环神经网络具有初始状态 $s_0$ ，在每个时间点 $t$ 迭代对当前时间的输入 $x_t$ 进行处理，修改自身的状态 $s_t$ ，并进行输出 $o_t$ 。
#
# 循环神经网络的核心是状态 $s$ ，是一个特定维数的向量，类似于神经网络的 “记忆”。在 $t=0$ 的初始时刻，$s_0$ 被赋予一个初始值（常用的为全 0 向量）。然后，我们用类似于递归的方法来描述循环神经网络的工作过程。即在 $t$ 时刻，我们假设 $s_{t-1}$ 已经求出，关注如何在此基础上求出 $s_{t}$ ：
#
# - 对输入向量 $x_t$ 通过矩阵 $U$ 进行线性变换，$U x_t$ 与状态 $s$ 具有相同的维度；
#
# - 对 $s_{t-1}$ 通过矩阵 $W$ 进行线性变换，$W s_{t-1}$ 与状态 $s$ 具有相同的维度；
#
# - 将上述得到的两个向量相加并通过激活函数，作为当前状态 $s_t$ 的值，即 $s_t = f(U x_t + W s_{t-1})$。也就是说，当前状态的值是上一个状态的值和当前输入进行某种信息整合而产生的；
#
# - 对当前状态 $s_t$ 通过矩阵 $V$ 进行线性变换，得到当前时刻的输出 $o_t$。

# %% [markdown]
# ![title](rnn_cell_zh.png)

# %% [markdown]
# ## 循环神经网络基本结构

# %% [markdown]
# RNN 常见的结构如下

# %% [markdown]
# ![titile](rnn.png)

# %% [markdown]
# 其中的单元 A 可以是全连接RNN，LSTM，GRU。
#
# tensorfow2.0中将这三个封装到以下接口中：
#
# - keras.layers.SimpleRNN
#
# - keras.layers.GRU
#
# - keras.layers.LSTM

# %% [markdown]
# 对于序列预测，如机器翻译，我们需要同时获得所有的单元A的输出$(h_0,h_1\cdots,h_t)$。对于分类和回归问题，则只需要最后一个单元输出$h_t$。这个过程通过参数 return_sequences=True 控制。

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np
import sklearn
import pandas as pd
import os
import sys
import time
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
num_words = 300
sequence_length = 300
embedding_dimension = 100

# 生成数据
def gen_datasets():
    '''
    generate train datasets and testing datasets from imdb data
    :return:
        x_train, y_train,
        x_test, y_test
    '''
    (x_train, y_train), (x_test, y_test) = keras.datasets.imdb.load_data(num_words=num_words)
    return  (x_train, y_train), (x_test, y_test)

(x_train, y_train), (x_test, y_test) = gen_datasets()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 24s 1us/step
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# C:\Users\陈继延\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\datasets\imdb.py:159: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# C:\Users\陈继延\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\datasets\imdb.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_test, y_test = np.array(xs[idx:]), np.array(labels[idx:])

# %%
word_index = keras.datasets.imdb.get_word_index()
print(len(word_index))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1646592/1641221 [==============================] - 3s 2us/step
# 88584

# %%
(x_train, y_train), (x_test, y_test) = gen_datasets()
x_train = pad_sequences(x_train, maxlen=sequence_length) 
x_test = pad_sequences(x_test,maxlen=sequence_length)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# C:\Users\陈继延\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\datasets\imdb.py:159: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# (25000, 300)
# (25000, 300)
# (25000,)
# (25000,)
# C:\Users\陈继延\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\datasets\imdb.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_test, y_test = np.array(xs[idx:]), np.array(labels[idx:])

# %% [markdown]
# ## 单向RNN

# %%
embedding_dimension = 100
single_rnn_model = keras.models.Sequential([
    layers.Embedding(input_dim=num_words,
                     output_dim=embedding_dimension,
                     input_length=sequence_length),
    layers.SimpleRNN(units=64, return_sequences=False),  #False 只返回最后一层
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

single_rnn_model.compile(optimizer=keras.optimizers.Adam(),
                         loss=keras.losses.BinaryCrossentropy(),
                         metrics=['accuracy'])

single_rnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 300, 100)          30000
# _________________________________________________________________
# simple_rnn (SimpleRNN)       (None, 64)                10560
# _________________________________________________________________
# dense (Dense)                (None, 64)                4160
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 44,785
# Trainable params: 44,785
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = single_rnn_model.fit(x_train, y_train, batch_size=64, epochs=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 352/352 [==============================] - 20s 54ms/step - loss: 0.6942 - accuracy: 0.5203 - val_loss: 0.6768 - val_accuracy: 0.5752
# Epoch 2/10
# 352/352 [==============================] - 18s 51ms/step - loss: 0.6475 - accuracy: 0.6238 - val_loss: 0.6797 - val_accuracy: 0.5680
# Epoch 3/10
# 352/352 [==============================] - 19s 53ms/step - loss: 0.6048 - accuracy: 0.6706 - val_loss: 0.5993 - val_accuracy: 0.6776
# Epoch 4/10
# 352/352 [==============================] - 19s 53ms/step - loss: 0.6340 - accuracy: 0.6512 - val_loss: 0.6419 - val_accuracy: 0.6220
# Epoch 5/10
# 352/352 [==============================] - 19s 54ms/step - loss: 0.6062 - accuracy: 0.6736 - val_loss: 0.5741 - val_accuracy: 0.7084
# Epoch 6/10
# 352/352 [==============================] - 19s 53ms/step - loss: 0.5685 - accuracy: 0.7035 - val_loss: 0.6784 - val_accuracy: 0.5536
# Epoch 7/10
# 352/352 [==============================] - 19s 54ms/step - loss: 0.6560 - accuracy: 0.5945 - val_loss: 0.6398 - val_accuracy: 0.6360
# Epoch 8/10
# 352/352 [==============================] - 19s 53ms/step - loss: 0.6357 - accuracy: 0.6341 - val_loss: 0.6870 - val_accuracy: 0.5444
# Epoch 9/10
# 352/352 [==============================] - 19s 53ms/step - loss: 0.6691 - accuracy: 0.5694 - val_loss: 0.6745 - val_accuracy: 0.5668
# Epoch 10/10
# 352/352 [==============================] - 19s 54ms/step - loss: 0.6635 - accuracy: 0.5738 - val_loss: 0.6828 - val_accuracy: 0.5424

# %% [markdown]
# ## 单向 LSTM

# %%
embedding_dimension = 100
single_lstm_model = keras.models.Sequential([
    layers.Embedding(input_dim=num_words,
                     output_dim=embedding_dimension,
                     input_length=sequence_length),
    #     layers.SimpleRNN(units = 64, return_sequences = False),#False 只返回最后一层
    layers.LSTM(units=64, return_sequences=False),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

single_lstm_model.compile(optimizer=keras.optimizers.Adam(),
                          loss=keras.losses.BinaryCrossentropy(),
                          metrics=['accuracy'])

single_lstm_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 300, 100)          30000
# _________________________________________________________________
# lstm (LSTM)                  (None, 64)                42240
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 76,465
# Trainable params: 76,465
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = single_lstm_model.fit(x_train, y_train, batch_size=64, epochs=10, validation_split=0.1)
# Out:
# Train on 22500 samples, validate on 2500 samples
# Epoch 1/10
# 22500/22500 [==============================] - 56s 2ms/sample - loss: 0.5663 - accuracy: 0.7052 - val_loss: 0.5049 - val_accuracy: 0.7548
# Epoch 2/10
# 22500/22500 [==============================] - 54s 2ms/sample - loss: 0.4658 - accuracy: 0.7827 - val_loss: 0.4723 - val_accuracy: 0.7848
# Epoch 3/10
# 22500/22500 [==============================] - 53s 2ms/sample - loss: 0.4548 - accuracy: 0.7871 - val_loss: 0.4786 - val_accuracy: 0.7740
# Epoch 4/10
# 22500/22500 [==============================] - 53s 2ms/sample - loss: 0.4353 - accuracy: 0.7979 - val_loss: 0.4652 - val_accuracy: 0.7804
# Epoch 5/10
# 22500/22500 [==============================] - 53s 2ms/sample - loss: 0.4297 - accuracy: 0.7996 - val_loss: 0.4578 - val_accuracy: 0.7912
# Epoch 6/10
# 22500/22500 [==============================] - 53s 2ms/sample - loss: 0.4225 - accuracy: 0.8062 - val_loss: 0.4526 - val_accuracy: 0.7912
# Epoch 7/10
# 22500/22500 [==============================] - 53s 2ms/sample - loss: 0.4175 - accuracy: 0.8066 - val_loss: 0.5050 - val_accuracy: 0.7600
# Epoch 8/10
# 22500/22500 [==============================] - 53s 2ms/sample - loss: 0.4064 - accuracy: 0.8173 - val_loss: 0.4376 - val_accuracy: 0.7936
# Epoch 9/10
# 22500/22500 [==============================] - 54s 2ms/sample - loss: 0.4145 - accuracy: 0.8105 - val_loss: 0.4408 - val_accuracy: 0.7956
# Epoch 10/10
# 22500/22500 [==============================] - 53s 2ms/sample - loss: 0.3907 - accuracy: 0.8230 - val_loss: 0.4432 - val_accuracy: 0.8044

# %% [markdown]
# ## 双向结构

# %% [markdown]
# ![title](bidirection.png)

# %%
embedding_dimension = 100
bidirection_lstm_model = keras.models.Sequential([
    layers.Embedding(input_dim=num_words,
                     output_dim=embedding_dimension,
                     input_length=sequence_length),
    layers.Bidirectional(layers.LSTM(units=64,
                                     return_sequences=True)),  # True 返回多层
    layers.Bidirectional(layers.LSTM(units=64, return_sequences=False)),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

bidirection_lstm_model.compile(optimizer=keras.optimizers.Adam(),
                               loss=keras.losses.BinaryCrossentropy(),
                               metrics=['accuracy'])

bidirection_lstm_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 300, 100)          30000
# _________________________________________________________________
# bidirectional (Bidirectional (None, 300, 128)          84480
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 128)               98816
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 221,617
# Trainable params: 221,617
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = bidirection_lstm_model.fit(x_train, y_train, batch_size=64, epochs=10, validation_split=0.1)
# Out:
# Train on 22500 samples, validate on 2500 samples
# Epoch 1/10
# 22500/22500 [==============================] - 301s 13ms/sample - loss: 0.5877 - accuracy: 0.6836 - val_loss: 0.5110 - val_accuracy: 0.7588
# Epoch 2/10
# 22500/22500 [==============================] - 300s 13ms/sample - loss: 0.4836 - accuracy: 0.7731 - val_loss: 0.4913 - val_accuracy: 0.7776
# Epoch 3/10
# 22500/22500 [==============================] - 299s 13ms/sample - loss: 0.4499 - accuracy: 0.7932 - val_loss: 0.4812 - val_accuracy: 0.7756
# Epoch 4/10
# 22500/22500 [==============================] - 302s 13ms/sample - loss: 0.4413 - accuracy: 0.7957 - val_loss: 0.4617 - val_accuracy: 0.7856
# Epoch 5/10
# 22500/22500 [==============================] - 298s 13ms/sample - loss: 0.4326 - accuracy: 0.8009 - val_loss: 0.5164 - val_accuracy: 0.7392
# Epoch 6/10
# 22500/22500 [==============================] - 300s 13ms/sample - loss: 0.4237 - accuracy: 0.8052 - val_loss: 0.4946 - val_accuracy: 0.7756
# Epoch 7/10
# 22500/22500 [==============================] - 301s 13ms/sample - loss: 0.4122 - accuracy: 0.8120 - val_loss: 0.4888 - val_accuracy: 0.7788
# Epoch 8/10
# 22500/22500 [==============================] - 299s 13ms/sample - loss: 0.4066 - accuracy: 0.8152 - val_loss: 0.4360 - val_accuracy: 0.7960
# Epoch 9/10
# 22500/22500 [==============================] - 301s 13ms/sample - loss: 0.3982 - accuracy: 0.8189 - val_loss: 0.4209 - val_accuracy: 0.8096
# Epoch 10/10
# 22500/22500 [==============================] - 309s 14ms/sample - loss: 0.3894 - accuracy: 0.8261 - val_loss: 0.4253 - val_accuracy: 0.8072

# %% [markdown]
# ## 测试

# %%
result = bidirection_lstm_model.evaluate(x_test, y_test)
print("loss=%s,accuracy=%s" %(result[0],result[1]))
# Out:
# 25000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# loss=0.41429665595054627,accuracy=0.8064
