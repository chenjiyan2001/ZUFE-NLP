# %% [markdown]
# # 使用sklearn_crfsuite模块训练crf模型

# %% [markdown]
# sklearn-crfsuite是基于CRFsuite库的一款轻量级的CRF库。该库兼容sklearn的算法，因此可以结合sklearn库的算法设计实体识别系统。sklearn-crfsuite不仅提供了条件随机场的训练和预测方法还提供了评测方法。

# %% [markdown]
# 安装：pip install sklearn-crfsuite

# %% [markdown]
# 官方文档：https://sklearn-crfsuite.readthedocs.io/en/latest/

# %%
# !pip install sklearn_crfsuite
# Out:
# Collecting sklearn_crfsuite
#   Downloading sklearn_crfsuite-0.3.6-py2.py3-none-any.whl (12 kB)
# Collecting python-crfsuite>=0.8.3
#   Downloading python_crfsuite-0.9.7-cp37-cp37m-win_amd64.whl (154 kB)
# Requirement already satisfied: six in c:\users\陈继延\appdata\roaming\python\python37\site-packages (from sklearn_crfsuite) (1.15.0)
# Requirement already satisfied: tqdm>=2.0 in c:\users\陈继延\appdata\roaming\python\python37\site-packages (from sklearn_crfsuite) (4.56.0)
# Requirement already satisfied: tabulate in d:\anaconda3\lib\site-packages (from sklearn_crfsuite) (0.8.9)
# Installing collected packages: python-crfsuite, sklearn-crfsuite
# Successfully installed python-crfsuite-0.9.7 sklearn-crfsuite-0.3.6

# %% [markdown]
# ## 导入需要的模块

# %%
import sklearn_crfsuite
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics

# %% [markdown]
# ## 读取数据

# %%
def read_data(file):   
    fr = open(file,encoding="utf-8")
    ret_sents = []
    tmp = []
    for line in fr:
        line = line.strip()
        if line == "":
            ret_sents.append(tmp)
            tmp = []
            continue
        line = line.split("\t")
        if len(line) != 2:
            continue
        tmp.append((line[0],line[1]))
    return ret_sents

train_sents = read_data("msra/train_data")
test_sents = read_data("msra/test_data")

# %% [markdown]
# ### 定义特征并转换语料

# %%
def word2features(sent, i):
    word = sent[i][0]
    
    features = {
        'bias': 1.0,
        'word': word,      
    }
    if i > 0:
        word1 = sent[i-1][0]
        features.update({
            '-1:word': word1,
        })
    else:
        features['BOS'] = True
        
    if i > 1:
        word2 = sent[i-2][0]
        features.update({
            '-2:word': word2
        })
        
    if i < len(sent)-1:
        word1 = sent[i+1][0]
        features.update({
            '+1:word': word1,
        })
    else:
        features['EOS'] = True
        
    if i < len(sent)-2:
        word2 = sent[i+2][0]
        features.update({
            '+2:word': word2,
        })
                
    return features


def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [label for token,label in sent]

def sent2tokens(sent):
    return [token for token,label in sent]

# %%
X_train = [sent2features(s) for s in train_sents]
y_train = [sent2labels(s) for s in train_sents]

X_test = [sent2features(s) for s in test_sents]
y_test = [sent2labels(s) for s in test_sents]

# %% [markdown]
# ### 训练

# %%
# %%time
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs', 
    c1=0.1, 
    c2=0.1, 
    max_iterations=100, 
    all_possible_transitions=True
)
crf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <timed exec> in <module>()
#
# D:\Anaconda3\lib\site-packages\sklearn_crfsuite\estimator.py in fit(self, X, y, X_dev, y_dev)
#     329                 print("")
#     330
# --> 331         trainer.train(self.modelfile.name, holdout=-1 if X_dev is None else 1)
#     332         self.training_log_ = trainer.logparser
#     333         return self
#
# pycrfsuite\_pycrfsuite.pyx in pycrfsuite._pycrfsuite.BaseTrainer.train()
#
# D:\Anaconda3\lib\site-packages\pycrfsuite\_pycrfsuite.cp37-win_amd64.pyd in string.from_py.__pyx_convert_string_from_py_std__in_string()
#
# UnicodeEncodeError: 'ascii' codec can't encode characters in position 9-11: ordinal not in range(128)

# %%
# 转移特征及权重
crf.transition_features_
# Out:
# {('O', 'O'): 3.770691,
#  ('O', 'B-LOC'): 0.188121,
#  ('O', 'I-LOC'): -9.183171,
#  ('O', 'B-ORG'): -0.359881,
#  ('O', 'I-ORG'): -9.002781,
#  ('O', 'B-PER'): -0.429625,
#  ('O', 'I-PER'): -8.421054,
#  ('B-LOC', 'O'): -1.288199,
#  ('B-LOC', 'B-LOC'): -1.279092,
#  ('B-LOC', 'I-LOC'): 3.899732,
#  ('B-LOC', 'B-ORG'): -6.498161,
#  ('B-LOC', 'I-ORG'): -8.78877,
#  ('B-LOC', 'B-PER'): -7.099309,
#  ('B-LOC', 'I-PER'): -6.864922,
#  ('I-LOC', 'O'): -0.476086,
#  ('I-LOC', 'B-LOC'): -1.090046,
#  ('I-LOC', 'I-LOC'): 3.552982,
#  ('I-LOC', 'B-ORG'): -5.550098,
#  ('I-LOC', 'I-ORG'): -9.640868,
#  ('I-LOC', 'B-PER'): -4.283422,
#  ('I-LOC', 'I-PER'): -7.681232,
#  ('B-ORG', 'O'): -3.27917,
#  ('B-ORG', 'B-LOC'): -5.181805,
#  ('B-ORG', 'I-LOC'): -5.533095,
#  ('B-ORG', 'B-ORG'): -2.446341,
#  ('B-ORG', 'I-ORG'): 4.579519,
#  ('B-ORG', 'B-PER'): -4.818339,
#  ('B-ORG', 'I-PER'): -5.451564,
#  ('I-ORG', 'O'): -0.362844,
#  ('I-ORG', 'B-LOC'): -2.382928,
#  ('I-ORG', 'I-LOC'): -7.110184,
#  ('I-ORG', 'B-ORG'): -4.371057,
#  ('I-ORG', 'I-ORG'): 5.34612,
#  ('I-ORG', 'B-PER'): -3.567738,
#  ('I-ORG', 'I-PER'): -6.59661,
#  ('B-PER', 'O'): -0.837943,
#  ('B-PER', 'B-LOC'): -4.958653,
#  ('B-PER', 'I-LOC'): -5.476789,
#  ('B-PER', 'B-ORG'): -4.629461,
#  ('B-PER', 'I-ORG'): -5.835446,
#  ('B-PER', 'B-PER'): -2.528848,
#  ('B-PER', 'I-PER'): 4.561175,
#  ('I-PER', 'O'): 0.021242,
#  ('I-PER', 'B-LOC'): -5.436375,
#  ('I-PER', 'I-LOC'): -6.263398,
#  ('I-PER', 'B-ORG'): -4.07676,
#  ('I-PER', 'I-ORG'): -6.670058,
#  ('I-PER', 'B-PER'): -2.537561,
#  ('I-PER', 'I-PER'): 2.823652}

# %%
# 状态特征及权重
crf.state_features_
# Out:
# {('bias', 'O'): 1.092168,
#  ('bias', 'B-LOC'): -0.592062,
#  ('bias', 'I-LOC'): -0.173155,
#  ('bias', 'B-ORG'): -0.926908,
#  ('bias', 'I-ORG'): -0.928595,
#  ('bias', 'B-PER'): -1.443082,
#  ('bias', 'I-PER'): -0.134878,
#  ('word:当', 'O'): 3.415742,
#  ('word:当', 'I-LOC'): -0.362896,
#  ('word:当', 'B-ORG'): -0.241426,
#  ('word:当', 'I-ORG'): -0.577074,
#  ('word:当', 'I-PER'): 0.155251,
#  ('BOS', 'O'): 2.336037,
#  ('BOS', 'B-LOC'): 1.852237,
#  ('BOS', 'B-ORG'): 1.68277,
#  ('BOS', 'I-ORG'): -5.110783,
#  ('BOS', 'B-PER'): 1.736904,
#  ('BOS', 'I-PER'): -3.953563,
#  ('+1:word:希', 'O'): -1.348802,
#  ('+1:word:希', 'B-LOC'): 1.815173,
#  ('+1:word:希', 'I-LOC'): -0.393703,
#  ('+1:word:希', 'B-ORG'): 0.002865,
#  ('+1:word:希', 'I-ORG'): 0.059517,
#  ('+1:word:希', 'B-PER'): 0.257977,
#  ('+1:word:希', 'I-PER'): -0.051414,
#  ('+2:word:望', 'O'): 0.042823,
#  ('+2:word:望', 'B-LOC'): -0.840629,
#  ('+2:word:望', 'I-LOC'): -0.063721,
#  ('+2:word:望', 'B-ORG'): -0.377318,
#  ('+2:word:望', 'I-ORG'): 0.729842,
#  ('+2:word:望', 'I-PER'): 0.481718,
#  ('word:希', 'O'): -0.636245,
#  ('word:希', 'B-LOC'): 1.07386,
#  ('word:希', 'I-LOC'): -2.581075,
#  ('word:希', 'B-ORG'): 0.35879,
#  ('word:希', 'I-ORG'): -0.34972,
#  ('word:希', 'B-PER'): 1.184858,
#  ('word:希', 'I-PER'): -0.386901,
#  ('-1:word:当', 'O'): 0.263975,
#  ('-1:word:当', 'B-LOC'): 0.185315,
#  ('-1:word:当', 'B-ORG'): 0.156236,
#  ('-1:word:当', 'I-ORG'): -0.14907,
#  ('-1:word:当', 'B-PER'): 1.558241,
#  ('-1:word:当', 'I-PER'): 0.713178,
#  ('+1:word:望', 'O'): 1.073761,
#  ('+1:word:望', 'B-LOC'): -0.547022,
#  ('+1:word:望', 'I-LOC'): -1.486318,
#  ('+1:word:望', 'B-ORG'): 0.42265,
#  ('+1:word:望', 'I-ORG'): -0.456235,
#  ('+1:word:望', 'B-PER'): -0.303995,
#  ('+1:word:望', 'I-PER'): -1.026114,
#  ('+2:word:工', 'O'): -0.011233,
#  ('+2:word:工', 'B-LOC'): -0.036945,
#  ('+2:word:工', 'I-LOC'): -0.438213,
#  ('+2:word:工', 'B-ORG'): 0.075237,
#  ('+2:word:工', 'I-ORG'): 0.087277,
#  ('+2:word:工', 'B-PER'): -1.381723,
#  ('+2:word:工', 'I-PER'): -0.431441,
#  ('word:望', 'O'): 1.578689,
#  ('word:望', 'B-LOC'): -0.124663,
#  ('word:望', 'I-LOC'): -0.225307,
#  ('word:望', 'B-ORG'): -1.016371,
#  ('word:望', 'I-ORG'): 0.00991,
#  ('word:望', 'I-PER'): -1.426861,
#  ('-1:word:希', 'O'): -0.168637,
#  ('-1:word:希', 'I-LOC'): 1.477473,
#  ('-1:word:希', 'I-ORG'): 0.130537,
#  ('-1:word:希', 'I-PER'): 2.812186,
#  ('-2:word:当', 'O'): -0.726517,
#  ('-2:word:当', 'B-LOC'): 0.405586,
#  ('-2:word:当', 'I-LOC'): -0.584447,
#  ('-2:word:当', 'B-ORG'): 0.463912,
#  ('-2:word:当', 'I-ORG'): 0.021935,
#  ('-2:word:当', 'B-PER'): -0.023157,
#  ('-2:word:当', 'I-PER'): 0.338731,
#  ('+1:word:工', 'O'): -0.020989,
#  ('+1:word:工', 'B-LOC'): 0.743817,
#  ('+1:word:工', 'I-LOC'): 0.547438,
#  ('+1:word:工', 'B-ORG'): 0.020435,
#  ('+1:word:工', 'I-ORG'): 0.757779,
#  ('+1:word:工', 'B-PER'): -1.158618,
#  ('+1:word:工', 'I-PER'): -0.402303,
#  ('+2:word:程', 'O'): 0.110927,
#  ('+2:word:程', 'B-LOC'): -1.097028,
#  ('+2:word:程', 'I-LOC'): -0.032172,
#  ('+2:word:程', 'B-ORG'): -3.350108,
#  ('+2:word:程', 'I-ORG'): -0.000934,
#  ('+2:word:程', 'I-PER'): 0.407343,
#  ('word:工', 'O'): 0.293952,
#  ('word:工', 'B-LOC'): -2.868313,
#  ('word:工', 'I-LOC'): -3.0072,
#  ('word:工', 'B-ORG'): 0.293627,
#  ('word:工', 'I-ORG'): -0.055479,
#  ('word:工', 'B-PER'): -1.432588,
#  ('word:工', 'I-PER'): -1.053475,
#  ('-1:word:望', 'O'): -1.83428,
#  ('-1:word:望', 'B-LOC'): 0.630504,
#  ('-1:word:望', 'I-LOC'): 1.506608,
#  ('-1:word:望', 'B-ORG'): 0.413585,
#  ('-1:word:望', 'I-ORG'): 0.028946,
#  ('-1:word:望', 'B-PER'): 0.41582,
#  ('-1:word:望', 'I-PER'): -0.27412,
#  ('-2:word:希', 'O'): 0.632584,
#  ('-2:word:希', 'B-LOC'): 1.076825,
#  ('-2:word:希', 'I-LOC'): -1.171043,
#  ('-2:word:希', 'B-ORG'): 0.112756,
#  ('-2:word:希', 'I-ORG'): -0.051409,
#  ('-2:word:希', 'B-PER'): 0.607902,
#  ('-2:word:希', 'I-PER'): -0.148454,
#  ('+1:word:程', 'O'): 0.706509,
#  ('+1:word:程', 'I-LOC'): 1.317674,
#  ('+1:word:程', 'B-ORG'): -0.594472,
#  ('+1:word:程', 'I-ORG'): -0.003417,
#  ('+1:word:程', 'B-PER'): 1.964946,
#  ('+2:word:救', 'O'): 0.695095,
#  ('+2:word:救', 'I-LOC'): -1.408677,
#  ('+2:word:救', 'B-ORG'): -0.163251,
#  ('+2:word:救', 'I-ORG'): 0.346419,
#  ('+2:word:救', 'I-PER'): -1.21748,
#  ('word:程', 'O'): -0.395516,
#  ('word:程', 'B-LOC'): -1.798325,
#  ('word:程', 'I-LOC'): -1.151305,
#  ('word:程', 'I-ORG'): 0.002226,
#  ('word:程', 'B-PER'): 3.58193,
#  ('word:程', 'I-PER'): 1.421535,
#  ('-1:word:工', 'O'): -0.010945,
#  ('-1:word:工', 'B-LOC'): -2.246436,
#  ('-1:word:工', 'I-LOC'): 1.248615,
#  ('-1:word:工', 'I-ORG'): 0.988458,
#  ('-1:word:工', 'B-PER'): -0.016817,
#  ('-1:word:工', 'I-PER'): -0.384429,
#  ('-2:word:望', 'O'): -0.373612,
#  ('-2:word:望', 'B-LOC'): 0.153806,
#  ('-2:word:望', 'I-LOC'): -0.188156,
#  ('-2:word:望', 'B-ORG'): -0.427234,
#  ('-2:word:望', 'I-ORG'): 0.150565,
#  ('-2:word:望', 'B-PER'): -0.486844,
#  ('-2:word:望', 'I-PER'): 0.015271,
#  ('+1:word:救', 'O'): -0.182495,
#  ('+1:word:救', 'B-LOC'): 0.354615,
#  ('+1:word:救', 'I-LOC'): -0.169913,
#  ('+1:word:救', 'I-ORG'): 1.747229,
#  ('+1:word:救', 'I-PER'): -0.300897,
#  ('+2:word:助', 'O'): -0.34229,
#  ('+2:word:助', 'B-LOC'): -0.322386,
#  ('+2:word:助', 'I-LOC'): 1.094012,
#  ('+2:word:助', 'I-ORG'): 0.020189,
#  ('+2:word:助', 'B-PER'): 3e-06,
#  ('+2:word:助', 'I-PER'): 1.52295,
#  ('word:救', 'O'): 2.167448,
#  ('word:救', 'I-ORG'): 0.650872,
#  ('-1:word:程', 'O'): -0.030976,
#  ('-1:word:程', 'B-LOC'): -1.763009,
#  ('-1:word:程', 'I-LOC'): 0.141542,
#  ('-1:word:程', 'I-ORG'): 0.039265,
#  ('-1:word:程', 'I-PER'): -0.104042,
#  ('-2:word:工', 'O'): 0.011871,
#  ('-2:word:工', 'B-LOC'): -0.549149,
#  ('-2:word:工', 'I-LOC'): 2.023395,
#  ('-2:word:工', 'B-ORG'): -0.188508,
#  ('-2:word:工', 'I-ORG'): -0.09661,
#  ('-2:word:工', 'B-PER'): -0.731789,
#  ('-2:word:工', 'I-PER'): 0.979608,
#  ('+1:word:助', 'O'): 0.776392,
#  ('+1:word:助', 'I-LOC'): 1.095994,
#  ('+1:word:助', 'I-ORG'): -0.651193,
#  ('+1:word:助', 'I-PER'): 1.744951,
#  ('+2:word:的', 'O'): 0.899647,
#  ('+2:word:的', 'B-LOC'): -0.156798,
#  ('+2:word:的', 'I-LOC'): -0.055719,
#  ('+2:word:的', 'B-ORG'): -0.014474,
#  ('+2:word:的', 'I-ORG'): -0.006368,
#  ('+2:word:的', 'B-PER'): -0.599179,
#  ('+2:word:的', 'I-PER'): -0.144528,
#  ('word:助', 'O'): 2.486468,
#  ('word:助', 'I-ORG'): -0.211194,
#  ('word:助', 'I-PER'): 1.947746,
#  ('-1:word:救', 'O'): -0.297147,
#  ('-1:word:救', 'B-LOC'): 0.98571,
#  ('-1:word:救', 'B-ORG'): -0.00281,
#  ('-1:word:救', 'I-ORG'): 0.544538,
#  ('-1:word:救', 'B-PER'): 0.141475,
#  ('-2:word:程', 'O'): -0.040207,
#  ('-2:word:程', 'B-LOC'): -0.18641,
#  ('-2:word:程', 'I-LOC'): 2.191525,
#  ('-2:word:程', 'B-ORG'): -1.198728,
#  ('-2:word:程', 'I-ORG'): -0.020103,
#  ('-2:word:程', 'B-PER'): 0.066488,
#  ('-2:word:程', 'I-PER'): 0.306882,
#  ('+1:word:的', 'O'): -1.163249,
#  ('+1:word:的', 'B-LOC'): -1.108946,
#  ('+1:word:的', 'I-LOC'): 0.54496,
#  ('+1:word:的', 'B-ORG'): -0.559254,
#  ('+1:word:的', 'I-ORG'): 0.800773,
#  ('+1:word:的', 'B-PER'): -0.178084,
#  ('+1:word:的', 'I-PER'): 1.07234,
#  ('+2:word:百', 'O'): 0.00188,
#  ('+2:word:百', 'B-LOC'): -1.255691,
#  ('+2:word:百', 'I-LOC'): 0.030462,
#  ('+2:word:百', 'B-ORG'): 0.357894,
#  ('+2:word:百', 'I-ORG'): -0.339261,
#  ('+2:word:百', 'B-PER'): 0.500924,
#  ('+2:word:百', 'I-PER'): 0.595534,
#  ('word:的', 'O'): 5.46377,
#  ('word:的', 'B-LOC'): -0.74823,
#  ('word:的', 'I-LOC'): -0.464324,
#  ('word:的', 'I-ORG'): -1.166448,
#  ('word:的', 'I-PER'): -1.778164,
#  ('-1:word:助', 'O'): -0.288445,
#  ('-1:word:助', 'B-LOC'): 1.238647,
#  ('-1:word:助', 'B-ORG'): 0.697517,
#  ('-1:word:助', 'I-ORG'): -0.087813,
#  ('-1:word:助', 'B-PER'): -0.035185,
#  ('-2:word:救', 'O'): -0.329734,
#  ('-2:word:救', 'B-LOC'): -0.443381,
#  ('-2:word:救', 'I-LOC'): 0.754731,
#  ('-2:word:救', 'B-ORG'): -0.389998,
#  ('-2:word:救', 'I-ORG'): 0.810726,
#  ('-2:word:救', 'B-PER'): -1.24561,
#  ('-2:word:救', 'I-PER'): 0.263796,
#  ('+1:word:百', 'O'): -0.378861,
#  ('+1:word:百', 'B-LOC'): -1.287518,
#  ('+1:word:百', 'I-LOC'): 0.00452,
#  ('+1:word:百', 'B-ORG'): 0.11005,
#  ('+1:word:百', 'I-ORG'): 0.306052,
#  ('+1:word:百', 'B-PER'): 1.676668,
#  ('+1:word:百', 'I-PER'): -0.002989,
#  ('+2:word:万', 'O'): -0.004311,
#  ('+2:word:万', 'B-LOC'): -0.247788,
#  ('+2:word:万', 'I-LOC'): 0.034478,
#  ('+2:word:万', 'B-ORG'): 0.818725,
#  ('+2:word:万', 'I-ORG'): -2.45899,
#  ('+2:word:万', 'B-PER'): -0.175095,
#  ('+2:word:万', 'I-PER'): -0.627278,
#  ('word:百', 'O'): -0.027791,
#  ('word:百', 'B-LOC'): 1.104732,
#  ('word:百', 'I-LOC'): -0.577134,
#  ('word:百', 'B-ORG'): 1.208336,
#  ('word:百', 'I-ORG'): -1.040799,
#  ('word:百', 'B-PER'): 5.2e-05,
#  ('word:百', 'I-PER'): -0.857798,
#  ('-1:word:的', 'O'): -0.598354,
#  ('-1:word:的', 'B-LOC'): 0.6821,
#  ('-1:word:的', 'I-LOC'): 0.536382,
#  ('-1:word:的', 'B-ORG'): 1.26973,
#  ('-1:word:的', 'I-ORG'): -1.196437,
#  ('-1:word:的', 'B-PER'): 0.779852,
#  ('-1:word:的', 'I-PER'): -0.656489,
#  ('-2:word:助', 'O'): -0.149577,
#  ('-2:word:助', 'B-LOC'): -1.588427,
#  ('-2:word:助', 'I-LOC'): 0.002201,
#  ('-2:word:助', 'B-ORG'): -0.326616,
#  ('-2:word:助', 'I-ORG'): 0.501424,
#  ('-2:word:助', 'B-PER'): 0.424992,
#  ('-2:word:助', 'I-PER'): -0.029233,
#  ('+1:word:万', 'O'): 0.062264,
#  ('+1:word:万', 'I-LOC'): 0.153142,
#  ('+1:word:万', 'B-ORG'): -1.587803,
#  ('+1:word:万', 'I-ORG'): 0.038288,
#  ('+1:word:万', 'B-PER'): 0.527426,
#  ('+1:word:万', 'I-PER'): -0.535301,
#  ('+2:word:儿', 'O'): -0.036034,
#  ('+2:word:儿', 'I-LOC'): -0.630228,
#  ('+2:word:儿', 'B-ORG'): 0.508791,
#  ('+2:word:儿', 'I-ORG'): -0.818954,
#  ('+2:word:儿', 'B-PER'): -0.182495,
#  ('+2:word:儿', 'I-PER'): 0.60855,
#  ('word:万', 'O'): -0.368074,
#  ('word:万', 'B-LOC'): 0.033131,
#  ('word:万', 'I-LOC'): -2.374973,
#  ('word:万', 'B-ORG'): 1.846099,
#  ('word:万', 'I-ORG'): 0.911595,
#  ('word:万', 'B-PER'): -0.060853,
#  ('word:万', 'I-PER'): 1.058917,
#  ('-1:word:百', 'B-LOC'): -0.921598,
#  ('-1:word:百', 'I-LOC'): 2.626268,
#  ('-1:word:百', 'I-ORG'): -0.02522,
#  ('-1:word:百', 'I-PER'): -0.154928,
#  ('-2:word:的', 'O'): -0.099632,
#  ('-2:word:的', 'B-LOC'): -0.772345,
#  ('-2:word:的', 'I-LOC'): 0.271928,
#  ('-2:word:的', 'B-ORG'): -1.124078,
#  ('-2:word:的', 'I-ORG'): 0.037129,
#  ('-2:word:的', 'B-PER'): -1.234374,
#  ('-2:word:的', 'I-PER'): 0.029385,
#  ('+1:word:儿', 'O'): -0.396691,
#  ('+1:word:儿', 'B-LOC'): 0.131015,
#  ('+1:word:儿', 'I-LOC'): 0.826809,
#  ('+1:word:儿', 'B-ORG'): -1.424457,
#  ('+1:word:儿', 'I-ORG'): 0.27491,
#  ('+1:word:儿', 'B-PER'): -0.01112,
#  ('+1:word:儿', 'I-PER'): 0.289062,
#  ('+2:word:童', 'O'): -0.299378,
#  ('+2:word:童', 'B-LOC'): 1.26735,
#  ('+2:word:童', 'I-LOC'): 0.124568,
#  ('+2:word:童', 'B-ORG'): 0.620949,
#  ('+2:word:童', 'I-ORG'): -0.072434,
#  ('+2:word:童', 'B-PER'): 0.354472,
#  ('+2:word:童', 'I-PER'): 1.1984,
#  ('word:儿', 'O'): 0.559241,
#  ('word:儿', 'B-LOC'): -0.007662,
#  ('word:儿', 'I-LOC'): -0.566185,
#  ('word:儿', 'B-ORG'): -0.817233,
#  ('word:儿', 'I-ORG'): 0.051175,
#  ('word:儿', 'I-PER'): -0.836973,
#  ('-1:word:万', 'O'): -0.23013,
#  ('-1:word:万', 'B-LOC'): -0.26582,
#  ('-1:word:万', 'I-LOC'): 0.172147,
#  ('-1:word:万', 'I-ORG'): 1.419841,
#  ('-1:word:万', 'I-PER'): 2.350229,
#  ('-2:word:百', 'O'): 1.157227,
#  ('-2:word:百', 'I-LOC'): -0.760872,
#  ('-2:word:百', 'B-ORG'): 1.377307,
#  ('-2:word:百', 'I-ORG'): 0.001275,
#  ('-2:word:百', 'B-PER'): -0.307391,
#  ('-2:word:百', 'I-PER'): -1.616928,
#  ('+1:word:童', 'O'): 0.228558,
#  ('+1:word:童', 'B-LOC'): -0.231355,
#  ('+1:word:童', 'I-LOC'): -2.788607,
#  ('+1:word:童', 'B-ORG'): 0.218753,
#  ('+1:word:童', 'I-ORG'): -0.003558,
#  ('+1:word:童', 'B-PER'): 0.92832,
#  ('+1:word:童', 'I-PER'): 0.289391,
#  ('+2:word:成', 'O'): -0.236557,
#  ('+2:word:成', 'B-LOC'): 0.358973,
#  ('+2:word:成', 'I-LOC'): 0.209405,
#  ('+2:word:成', 'B-ORG'): -0.043061,
#  ('+2:word:成', 'I-ORG'): 0.144828,
#  ('+2:word:成', 'B-PER'): -0.665092,
#  ('+2:word:成', 'I-PER'): -0.218599,
#  ('word:童', 'O'): 0.06021,
#  ('word:童', 'I-LOC'): 0.773374,
#  ('word:童', 'I-ORG'): 0.151966,
#  ('word:童', 'B-PER'): 0.14435,
#  ('word:童', 'I-PER'): 0.067813,
#  ('-1:word:儿', 'O'): 0.056686,
#  ('-1:word:儿', 'I-LOC'): 1.388672,
#  ('-1:word:儿', 'I-ORG'): 1.266563,
#  ('-1:word:儿', 'B-PER'): 1.405695,
#  ('-2:word:万', 'O'): 0.023949,
#  ('-2:word:万', 'B-LOC'): 0.21214,
#  ('-2:word:万', 'I-LOC'): 0.310833,
#  ('-2:word:万', 'B-ORG'): 0.766419,
#  ('-2:word:万', 'I-ORG'): -0.905621,
#  ('-2:word:万', 'B-PER'): -0.294465,
#  ('-2:word:万', 'I-PER'): -1.802155,
#  ('+1:word:成', 'O'): -0.048307,
#  ('+1:word:成', 'B-LOC'): 1.4e-05,
#  ('+1:word:成', 'I-LOC'): -0.001669,
#  ('+1:word:成', 'B-ORG'): 0.548016,
#  ('+1:word:成', 'I-ORG'): 0.724065,
#  ('+1:word:成', 'B-PER'): -0.559859,
#  ('+1:word:成', 'I-PER'): -0.361879,
#  ('+2:word:长', 'O'): -1.49916,
#  ('+2:word:长', 'B-LOC'): -0.27187,
#  ('+2:word:长', 'I-LOC'): 0.128899,
#  ('+2:word:长', 'B-ORG'): 1.358339,
#  ('+2:word:长', 'I-ORG'): 0.76897,
#  ('+2:word:长', 'B-PER'): 1.865183,
#  ('+2:word:长', 'I-PER'): 1.020331,
#  ('word:成', 'O'): 0.002952,
#  ('word:成', 'B-LOC'): 0.441163,
#  ('word:成', 'I-LOC'): -2.551728,
#  ('word:成', 'B-ORG'): 0.048001,
#  ('word:成', 'I-ORG'): -4.065659,
#  ('word:成', 'B-PER'): 0.195317,
#  ('word:成', 'I-PER'): 0.951007,
#  ('-1:word:童', 'O'): -0.315604,
#  ('-1:word:童', 'I-LOC'): 0.982974,
#  ('-1:word:童', 'I-ORG'): 0.327543,
#  ('-1:word:童', 'B-PER'): -0.141918,
#  ('-1:word:童', 'I-PER'): 1.564559,
#  ('-2:word:儿', 'O'): -0.149224,
#  ('-2:word:儿', 'B-LOC'): 0.193302,
#  ('-2:word:儿', 'I-LOC'): -0.939123,
#  ('-2:word:儿', 'B-ORG'): -1.710938,
#  ('-2:word:儿', 'I-ORG'): 0.01012,
#  ('-2:word:儿', 'B-PER'): 1.851047,
#  ('-2:word:儿', 'I-PER'): 0.212271,
#  ('+1:word:长', 'O'): 0.927223,
#  ('+1:word:长', 'B-LOC'): 0.510828,
#  ('+1:word:长', 'I-LOC'): -1.313048,
#  ('+1:word:长', 'B-ORG'): 1.717497,
#  ('+1:word:长', 'I-ORG'): -0.188054,
#  ('+1:word:长', 'B-PER'): 0.447715,
#  ('+1:word:长', 'I-PER'): -5.08218,
#  ('+2:word:起', 'O'): -0.045102,
#  ('+2:word:起', 'B-LOC'): -0.366783,
#  ('+2:word:起', 'I-LOC'): -0.027119,
#  ('+2:word:起', 'B-ORG'): -0.693862,
#  ('+2:word:起', 'I-ORG'): 0.183246,
#  ('+2:word:起', 'B-PER'): 0.5774,
#  ('+2:word:起', 'I-PER'): -0.011541,
#  ('word:长', 'O'): 0.362189,
#  ('word:长', 'B-LOC'): 1.343579,
#  ('word:长', 'I-LOC'): -2.567893,
#  ('word:长', 'B-ORG'): 0.100974,
#  ('word:长', 'I-ORG'): -2.375344,
#  ('word:长', 'B-PER'): -2.234595,
#  ('word:长', 'I-PER'): -0.090503,
#  ('-1:word:成', 'O'): -0.68357,
#  ('-1:word:成', 'B-LOC'): 0.943726,
#  ('-1:word:成', 'I-LOC'): 1.631162,
#  ('-1:word:成', 'B-ORG'): -0.443742,
#  ('-1:word:成', 'I-ORG'): 0.00407,
#  ('-1:word:成', 'B-PER'): -1.304634,
#  ('-1:word:成', 'I-PER'): 0.018828,
#  ('-2:word:童', 'O'): 0.005545,
#  ('-2:word:童', 'B-LOC'): -0.047415,
#  ('-2:word:童', 'I-LOC'): -0.001257,
#  ('-2:word:童', 'B-ORG'): 0.296301,
#  ('-2:word:童', 'I-ORG'): -0.513262,
#  ('-2:word:童', 'I-PER'): 0.764206,
#  ('+1:word:起', 'O'): 1.232732,
#  ('+1:word:起', 'I-LOC'): 0.963727,
#  ('+1:word:起', 'I-ORG'): 0.10647,
#  ('+1:word:起', 'B-PER'): -0.926102,
#  ('+1:word:起', 'I-PER'): -0.003678,
#  ('+2:word:来', 'O'): -0.098807,
#  ('+2:word:来', 'B-LOC'): -0.215692,
#  ('+2:word:来', 'I-LOC'): -0.225537,
#  ('+2:word:来', 'B-ORG'): -1.237377,
#  ('+2:word:来', 'I-ORG'): 0.117706,
#  ('+2:word:来', 'B-PER'): -0.131036,
#  ('+2:word:来', 'I-PER'): -0.002405,
#  ('word:起', 'O'): 0.988311,
#  ('word:起', 'I-LOC'): -0.63106,
#  ('word:起', 'B-ORG'): -0.024816,
#  ('word:起', 'I-ORG'): -0.229857,
#  ('word:起', 'I-PER'): 2.124513,
#  ('-1:word:长', 'O'): -1.888126,
#  ('-1:word:长', 'B-LOC'): -0.657562,
#  ('-1:word:长', 'I-LOC'): 1.597082,
#  ('-1:word:长', 'B-ORG'): -1.938479,
#  ('-1:word:长', 'I-ORG'): 0.009722,
#  ('-1:word:长', 'B-PER'): 2.581883,
#  ('-1:word:长', 'I-PER'): 0.639444,
#  ('-2:word:成', 'O'): 0.016531,
#  ('-2:word:成', 'B-LOC'): -0.013085,
#  ('-2:word:成', 'I-LOC'): -1.252044,
#  ('-2:word:成', 'B-ORG'): 0.180983,
#  ('-2:word:成', 'I-ORG'): -0.354149,
#  ('-2:word:成', 'B-PER'): -0.718101,
#  ('-2:word:成', 'I-PER'): 0.675644,
#  ('+1:word:来', 'O'): -0.514454,
#  ('+1:word:来', 'B-LOC'): -0.075952,
#  ('+1:word:来', 'I-LOC'): -0.171295,
#  ('+1:word:来', 'B-ORG'): 0.921225,
#  ('+1:word:来', 'I-ORG'): -0.24852,
#  ('+1:word:来', 'B-PER'): 0.843021,
#  ('+1:word:来', 'I-PER'): 0.073584,
#  ('+2:word:，', 'O'): 0.911419,
#  ('+2:word:，', 'B-LOC'): -0.58141,
#  ('+2:word:，', 'I-LOC'): -0.149417,
#  ('+2:word:，', 'B-ORG'): -0.21326,
#  ('+2:word:，', 'I-ORG'): -0.153706,
#  ('+2:word:，', 'B-PER'): -0.086091,
#  ('+2:word:，', 'I-PER'): -0.029526,
#  ('word:来', 'O'): 1.304052,
#  ('word:来', 'B-LOC'): -1.301956,
#  ('word:来', 'I-LOC'): -0.039068,
#  ('word:来', 'B-ORG'): -2.797403,
#  ('word:来', 'I-ORG'): -0.234824,
#  ('word:来', 'I-PER'): 0.45649,
#  ('-1:word:起', 'O'): -0.4488,
#  ('-1:word:起', 'B-LOC'): -0.013797,
#  ('-1:word:起', 'I-LOC'): -1.369748,
#  ('-1:word:起', 'B-ORG'): 0.794955,
#  ('-1:word:起', 'I-ORG'): 0.397982,
#  ('-1:word:起', 'B-PER'): 1.18726,
#  ('-1:word:起', 'I-PER'): -0.626328,
#  ('-2:word:长', 'O'): -0.123512,
#  ('-2:word:长', 'B-LOC'): -0.799566,
#  ('-2:word:长', 'I-LOC'): -1.495412,
#  ('-2:word:长', 'B-ORG'): 0.317562,
#  ('-2:word:长', 'I-ORG'): 0.141676,
#  ('-2:word:长', 'B-PER'): 0.37928,
#  ('-2:word:长', 'I-PER'): 1.378331,
#  ('+1:word:，', 'O'): -0.916842,
#  ('+1:word:，', 'B-LOC'): -2.104212,
#  ('+1:word:，', 'I-LOC'): 0.56254,
#  ('+1:word:，', 'B-ORG'): -0.570938,
#  ('+1:word:，', 'I-ORG'): 0.63392,
#  ('+1:word:，', 'B-PER'): -0.92892,
#  ('+1:word:，', 'I-PER'): 0.468349,
#  ('+2:word:科', 'O'): -0.024428,
#  ('+2:word:科', 'B-LOC'): 1.014867,
#  ('+2:word:科', 'I-LOC'): 0.201998,
#  ('+2:word:科', 'B-ORG'): -0.005104,
#  ('+2:word:科', 'I-ORG'): 0.009068,
#  ('+2:word:科', 'B-PER'): -1.018553,
#  ('+2:word:科', 'I-PER'): -0.115885,
#  ('word:，', 'O'): 9.55944,
#  ('word:，', 'I-LOC'): 1.838587,
#  ('-1:word:来', 'O'): -0.904628,
#  ('-1:word:来', 'B-LOC'): 1.918362,
#  ('-1:word:来', 'I-LOC'): 0.538009,
#  ('-1:word:来', 'B-ORG'): -0.676112,
#  ('-1:word:来', 'I-ORG'): -0.125802,
#  ('-1:word:来', 'B-PER'): -0.784997,
#  ('-1:word:来', 'I-PER'): -1.775516,
#  ('-2:word:起', 'O'): -0.173163,
#  ('-2:word:起', 'B-LOC'): 0.102745,
#  ('-2:word:起', 'I-LOC'): 1.41726,
#  ('-2:word:起', 'B-ORG'): -0.003154,
#  ('-2:word:起', 'I-ORG'): 0.011891,
#  ('-2:word:起', 'B-PER'): -0.987543,
#  ('-2:word:起', 'I-PER'): 0.308044,
#  ('+1:word:科', 'O'): -0.308596,
#  ('+1:word:科', 'B-LOC'): 0.165142,
#  ('+1:word:科', 'I-LOC'): 0.093411,
#  ('+1:word:科', 'B-ORG'): 1.807265,
#  ('+1:word:科', 'I-ORG'): 0.023895,
#  ('+1:word:科', 'B-PER'): -0.494977,
#  ('+1:word:科', 'I-PER'): 0.826143,
#  ('+2:word:教', 'O'): -0.088607,
#  ('+2:word:教', 'B-LOC'): -0.568795,
#  ('+2:word:教', 'I-LOC'): 0.270505,
#  ('+2:word:教', 'B-ORG'): -0.008148,
#  ('+2:word:教', 'I-ORG'): 0.309359,
#  ('+2:word:教', 'B-PER'): -0.754214,
#  ('+2:word:教', 'I-PER'): 0.694177,
#  ('word:科', 'O'): -1.087987,
#  ('word:科', 'B-LOC'): 2.109462,
#  ('word:科', 'I-LOC'): -0.000146,
#  ('word:科', 'B-ORG'): 0.86633,
#  ('word:科', 'I-ORG'): 0.118154,
#  ('word:科', 'B-PER'): 1.068246,
#  ('word:科', 'I-PER'): 1.598848,
#  ('-1:word:，', 'O'): -1.169239,
#  ('-1:word:，', 'B-LOC'): 0.961705,
#  ('-1:word:，', 'I-LOC'): 1.010834,
#  ('-1:word:，', 'B-ORG'): 1.143347,
#  ('-1:word:，', 'B-PER'): 1.055773,
#  ('-2:word:来', 'O'): -0.05486,
#  ('-2:word:来', 'B-LOC'): 0.656124,
#  ('-2:word:来', 'I-LOC'): -0.412662,
#  ('-2:word:来', 'B-ORG'): 0.531329,
#  ('-2:word:来', 'I-ORG'): -0.082053,
#  ('-2:word:来', 'B-PER'): -0.014223,
#  ('-2:word:来', 'I-PER'): -1.461007,
#  ('+1:word:教', 'O'): -0.166628,
#  ('+1:word:教', 'B-LOC'): -1.809878,
#  ('+1:word:教', 'I-LOC'): -0.007295,
#  ('+1:word:教', 'B-ORG'): 0.268987,
#  ('+1:word:教', 'I-ORG'): 0.070319,
#  ('+1:word:教', 'B-PER'): 0.589181,
#  ('+1:word:教', 'I-PER'): 1.324329,
#  ('+2:word:兴', 'O'): 0.033805,
#  ('+2:word:兴', 'B-LOC'): -1.134665,
#  ('+2:word:兴', 'I-LOC'): 0.081385,
#  ('+2:word:兴', 'B-ORG'): -1.588357,
#  ('+2:word:兴', 'I-ORG'): -0.070817,
#  ('+2:word:兴', 'B-PER'): 0.449391,
#  ('+2:word:兴', 'I-PER'): 8.1e-05,
#  ('word:教', 'O'): 0.553129,
#  ('word:教', 'B-LOC'): -0.724479,
#  ('word:教', 'I-LOC'): -0.256692,
#  ('word:教', 'B-ORG'): 0.66359,
#  ('word:教', 'I-ORG'): -0.003878,
#  ('word:教', 'I-PER'): -2.095887,
#  ('-1:word:科', 'O'): 0.674516,
#  ('-1:word:科', 'B-LOC'): -1.161491,
#  ('-1:word:科', 'I-LOC'): -0.9676,
#  ('-1:word:科', 'I-ORG'): -0.62202,
#  ('-1:word:科', 'B-PER'): -0.606207,
#  ('-1:word:科', 'I-PER'): 0.440821,
#  ('-2:word:，', 'O'): -0.28011,
#  ('-2:word:，', 'B-LOC'): -0.353214,
#  ('-2:word:，', 'I-LOC'): 0.180766,
#  ('-2:word:，', 'B-ORG'): -0.444895,
#  ('-2:word:，', 'I-ORG'): 0.173959,
#  ('-2:word:，', 'B-PER'): -0.62271,
#  ('-2:word:，', 'I-PER'): 0.114779,
#  ('+1:word:兴', 'O'): -0.300991,
#  ('+1:word:兴', 'B-LOC'): 1.303989,
#  ('+1:word:兴', 'I-LOC'): 0.0516,
#  ('+1:word:兴', 'B-ORG'): 1.897354,
#  ('+1:word:兴', 'I-ORG'): -0.088298,
#  ('+1:word:兴', 'B-PER'): -1.158872,
#  ('+1:word:兴', 'I-PER'): 0.534736,
#  ('+2:word:国', 'O'): -0.191307,
#  ('+2:word:国', 'B-LOC'): -0.296187,
#  ('+2:word:国', 'I-LOC'): -0.033326,
#  ('+2:word:国', 'B-ORG'): 0.516612,
#  ('+2:word:国', 'I-ORG'): -0.213673,
#  ('+2:word:国', 'B-PER'): 0.068961,
#  ('+2:word:国', 'I-PER'): -0.308907,
#  ('word:兴', 'O'): -0.662412,
#  ('word:兴', 'B-LOC'): 0.982597,
#  ('word:兴', 'I-LOC'): -0.012399,
#  ('word:兴', 'B-ORG'): 0.242341,
#  ('word:兴', 'I-ORG'): 0.54048,
#  ('word:兴', 'I-PER'): 0.989599,
#  ('-1:word:教', 'O'): 0.160532,
#  ('-1:word:教', 'I-LOC'): 2.021117,
#  ('-1:word:教', 'I-ORG'): 0.550688,
#  ('-1:word:教', 'B-PER'): -0.129159,
#  ('-2:word:科', 'O'): 0.054327,
#  ('-2:word:科', 'B-LOC'): -0.390341,
#  ('-2:word:科', 'I-LOC'): 1.35617,
#  ('-2:word:科', 'B-ORG'): -0.665439,
#  ('-2:word:科', 'I-ORG'): -0.023833,
#  ('-2:word:科', 'B-PER'): -0.454054,
#  ('-2:word:科', 'I-PER'): -0.682014,
#  ('+1:word:国', 'O'): -0.75091,
#  ('+1:word:国', 'B-LOC'): 0.769872,
#  ('+1:word:国', 'I-LOC'): -0.830734,
#  ('+1:word:国', 'B-ORG'): 0.888608,
#  ('+1:word:国', 'I-ORG'): -0.208555,
#  ('+1:word:国', 'B-PER'): -1.743797,
#  ('+1:word:国', 'I-PER'): -0.655474,
#  ('+2:word:蔚', 'O'): 0.003133,
#  ('+2:word:蔚', 'B-ORG'): 0.033313,
#  ('word:国', 'O'): -1.490457,
#  ('word:国', 'B-LOC'): -1.022048,
#  ('word:国', 'I-LOC'): 2.677632,
#  ('word:国', 'B-ORG'): 1.550661,
#  ('word:国', 'I-ORG'): 0.335007,
#  ('word:国', 'B-PER'): -2.23232,
#  ('word:国', 'I-PER'): -0.046319,
#  ('-1:word:兴', 'O'): 0.146511,
#  ('-1:word:兴', 'B-LOC'): 0.953226,
#  ('-1:word:兴', 'I-LOC'): 0.204251,
#  ('-1:word:兴', 'I-ORG'): 0.178899,
#  ('-1:word:兴', 'I-PER'): -0.853735,
#  ('-2:word:教', 'O'): -0.07654,
#  ('-2:word:教', 'B-LOC'): -0.480886,
#  ('-2:word:教', 'I-LOC'): 0.06648,
#  ('-2:word:教', 'B-ORG'): -0.276429,
#  ('-2:word:教', 'I-ORG'): 0.019294,
#  ('-2:word:教', 'B-PER'): 1.651001,
#  ('-2:word:教', 'I-PER'): -0.33203,
#  ('+1:word:蔚', 'O'): 0.595038,
#  ('+1:word:蔚', 'I-LOC'): -0.009499,
#  ('+1:word:蔚', 'I-ORG'): 0.276536,
#  ('+1:word:蔚', 'B-PER'): 0.240776,
#  ('+2:word:然', 'O'): -0.221383,
#  ('+2:word:然', 'B-LOC'): -0.91341,
#  ('+2:word:然', 'I-LOC'): 0.437062,
#  ('+2:word:然', 'I-ORG'): 0.172928,
#  ('+2:word:然', 'B-PER'): 1.015367,
#  ('+2:word:然', 'I-PER'): 0.136716,
#  ('word:蔚', 'O'): -1.88879,
#  ('word:蔚', 'B-LOC'): 1.491413,
#  ('word:蔚', 'B-ORG'): 0.748594,
#  ('word:蔚', 'I-ORG'): -0.849269,
#  ('word:蔚', 'I-PER'): 1.544164,
#  ('-1:word:国', 'O'): 0.71989,
#  ('-1:word:国', 'B-LOC'): -0.552791,
#  ('-1:word:国', 'I-LOC'): -2.124062,
#  ('-1:word:国', 'B-ORG'): 0.165083,
#  ('-1:word:国', 'I-ORG'): 0.4992,
#  ('-1:word:国', 'B-PER'): 0.777662,
#  ('-1:word:国', 'I-PER'): 1.45788,
#  ('-2:word:兴', 'O'): -0.145518,
#  ('-2:word:兴', 'B-LOC'): 0.2967,
#  ('-2:word:兴', 'I-LOC'): 0.488256,
#  ('-2:word:兴', 'B-ORG'): 0.13499,
#  ('-2:word:兴', 'I-ORG'): 0.071987,
#  ('-2:word:兴', 'B-PER'): -0.823218,
#  ('+1:word:然', 'O'): 0.956587,
#  ('+1:word:然', 'I-LOC'): -0.284229,
#  ('+1:word:然', 'B-ORG'): -1.25095,
#  ('+1:word:然', 'I-ORG'): 0.027666,
#  ('+1:word:然', 'B-PER'): 1.173201,
#  ('+1:word:然', 'I-PER'): -0.835896,
#  ('word:然', 'O'): 0.060206,
#  ('word:然', 'I-LOC'): -0.4754,
#  ('word:然', 'I-ORG'): 0.036496,
#  ('word:然', 'I-PER'): 1.354782,
#  ('-1:word:蔚', 'O'): 0.050965,
#  ('-1:word:蔚', 'I-LOC'): 0.800841,
#  ('-1:word:蔚', 'I-ORG'): 0.000418,
#  ('-1:word:蔚', 'I-PER'): -1.212928,
#  ('-2:word:国', 'O'): 0.245672,
#  ('-2:word:国', 'B-LOC'): -0.149964,
#  ('-2:word:国', 'I-LOC'): 0.687811,
#  ('-2:word:国', 'B-ORG'): -0.470141,
#  ('-2:word:国', 'I-ORG'): 0.415815,
#  ('-2:word:国', 'B-PER'): -0.718906,
#  ('-2:word:国', 'I-PER'): -2.438196,
#  ('+2:word:风', 'O'): 0.538279,
#  ('+2:word:风', 'B-LOC'): 0.268151,
#  ('+2:word:风', 'I-LOC'): 0.263959,
#  ('+2:word:风', 'B-ORG'): -1.825151,
#  ('+2:word:风', 'I-ORG'): -0.268342,
#  ('+2:word:风', 'B-PER'): -0.766046,
#  ('+2:word:风', 'I-PER'): -0.699442,
#  ('-1:word:然', 'O'): 0.011565,
#  ('-1:word:然', 'B-LOC'): 1.347676,
#  ('-1:word:然', 'I-LOC'): -0.301643,
#  ('-1:word:然', 'I-ORG'): -0.007075,
#  ('-1:word:然', 'B-PER'): 0.832438,
#  ('-2:word:蔚', 'O'): 0.036396,
#  ('-2:word:蔚', 'I-ORG'): 0.677548,
#  ('-2:word:蔚', 'B-PER'): 0.53757,
#  ('+1:word:风', 'O'): -0.301063,
#  ('+1:word:风', 'B-LOC'): -0.144499,
#  ('+1:word:风', 'I-LOC'): 0.118929,
#  ('+1:word:风', 'B-ORG'): -0.140763,
#  ('+1:word:风', 'I-ORG'): 0.003693,
#  ('+1:word:风', 'B-PER'): 0.519351,
#  ('+1:word:风', 'I-PER'): -1.288607,
#  ('+2:word:时', 'O'): 0.070756,
#  ('+2:word:时', 'B-LOC'): -0.066828,
#  ('+2:word:时', 'I-LOC'): -0.608108,
#  ('+2:word:时', 'B-ORG'): 0.343399,
#  ('+2:word:时', 'I-ORG'): -0.068638,
#  ('+2:word:时', 'B-PER'): -0.360891,
#  ('+2:word:时', 'I-PER'): -0.377734,
#  ('word:风', 'O'): 0.450042,
#  ('word:风', 'B-LOC'): -1.056563,
#  ('word:风', 'I-LOC'): -0.529483,
#  ('word:风', 'B-ORG'): -0.076849,
#  ('word:风', 'I-ORG'): 0.182154,
#  ('word:风', 'I-PER'): 0.876986,
#  ('-2:word:然', 'O'): 0.139444,
#  ('-2:word:然', 'B-LOC'): -0.247534,
#  ('-2:word:然', 'I-LOC'): -0.391439,
#  ('-2:word:然', 'B-ORG'): -0.464623,
#  ('-2:word:然', 'I-ORG'): 0.229955,
#  ('-2:word:然', 'B-PER'): 0.172336,
#  ('-2:word:然', 'I-PER'): -0.033891,
#  ('+1:word:时', 'O'): 0.051027,
#  ('+1:word:时', 'B-LOC'): -1.148225,
#  ('+1:word:时', 'I-LOC'): 0.543124,
#  ('+1:word:时', 'B-ORG'): -0.911406,
#  ('+1:word:时', 'I-ORG'): 0.029827,
#  ('+1:word:时', 'B-PER'): 0.406545,
#  ('+1:word:时', 'I-PER'): 0.176473,
#  ('word:时', 'O'): 0.138817,
#  ('word:时', 'B-LOC'): -0.899463,
#  ('word:时', 'I-LOC'): 0.978691,
#  ('word:时', 'B-ORG'): -2.524406,
#  ('word:时', 'I-ORG'): -7e-06,
#  ('word:时', 'B-PER'): -1.402748,
#  ('word:时', 'I-PER'): -3.650073,
#  ('-1:word:风', 'O'): 1.413353,
#  ('-1:word:风', 'I-LOC'): 3.001726,
#  ('-1:word:风', 'I-ORG'): 1.016727,
#  ('-1:word:风', 'I-PER'): -0.529942,
#  ('+2:word:今', 'O'): -0.200984,
#  ('+2:word:今', 'B-LOC'): -0.886863,
#  ('+2:word:今', 'I-LOC'): -0.202238,
#  ('+2:word:今', 'B-ORG'): -0.111823,
#  ('+2:word:今', 'I-ORG'): 0.733926,
#  ('+2:word:今', 'B-PER'): -0.516087,
#  ('+2:word:今', 'I-PER'): 0.693827,
#  ('-1:word:时', 'O'): -0.47665,
#  ('-1:word:时', 'B-LOC'): -0.024055,
#  ('-1:word:时', 'I-LOC'): -2.478799,
#  ('-1:word:时', 'B-ORG'): 0.671388,
#  ('-1:word:时', 'I-ORG'): 0.016528,
#  ('-1:word:时', 'B-PER'): 0.637954,
#  ('-1:word:时', 'I-PER'): 0.325141,
#  ('-2:word:风', 'O'): -0.140406,
#  ('-2:word:风', 'B-LOC'): -0.006119,
#  ('-2:word:风', 'I-LOC'): 1.483662,
#  ('-2:word:风', 'B-ORG'): -0.004499,
#  ('-2:word:风', 'I-ORG'): 0.428424,
#  ('-2:word:风', 'B-PER'): -1.00487,
#  ('+1:word:今', 'O'): -1.267393,
#  ('+1:word:今', 'B-LOC'): 0.492991,
#  ('+1:word:今', 'I-LOC'): 0.482583,
#  ('+1:word:今', 'B-ORG'): 1.240835,
#  ('+1:word:今', 'I-ORG'): 0.296513,
#  ('+1:word:今', 'B-PER'): -0.005635,
#  ('+1:word:今', 'I-PER'): 1.384624,
#  ('+2:word:天', 'O'): -0.277156,
#  ('+2:word:天', 'B-LOC'): -0.484843,
#  ('+2:word:天', 'I-LOC'): -0.178524,
#  ('+2:word:天', 'B-ORG'): -0.310822,
#  ('+2:word:天', 'I-ORG'): 0.118992,
#  ('+2:word:天', 'B-PER'): 2.163653,
#  ('+2:word:天', 'I-PER'): 0.703076,
#  ('word:今', 'O'): 2.366948,
#  ('word:今', 'I-LOC'): -0.396736,
#  ('word:今', 'B-ORG'): 0.734759,
#  ('word:今', 'I-ORG'): -1.104501,
#  ('word:今', 'I-PER'): -0.129507,
#  ('-2:word:时', 'O'): -0.071797,
#  ('-2:word:时', 'B-LOC'): -0.106018,
#  ('-2:word:时', 'I-LOC'): 1.016572,
#  ('-2:word:时', 'B-ORG'): 0.034911,
#  ('-2:word:时', 'I-ORG'): 0.083952,
#  ('-2:word:时', 'B-PER'): 0.740176,
#  ('-2:word:时', 'I-PER'): 0.838391,
#  ('+1:word:天', 'O'): 0.31139,
#  ('+1:word:天', 'B-LOC'): -1.072848,
#  ('+1:word:天', 'I-LOC'): 0.138588,
#  ('+1:word:天', 'B-ORG'): -0.352951,
#  ('+1:word:天', 'I-ORG'): -0.033701,
#  ('+1:word:天', 'B-PER'): 0.334973,
#  ('+1:word:天', 'I-PER'): -1.355379,
#  ('+2:word:有', 'O'): -0.009114,
#  ('+2:word:有', 'B-LOC'): -0.535759,
#  ('+2:word:有', 'I-LOC'): 0.025702,
#  ('+2:word:有', 'B-ORG'): -0.075236,
#  ('+2:word:有', 'I-ORG'): 0.137688,
#  ('+2:word:有', 'B-PER'): 0.258701,
#  ('+2:word:有', 'I-PER'): -0.49391,
#  ('word:天', 'O'): 0.269236,
#  ('word:天', 'B-LOC'): 0.329412,
#  ('word:天', 'I-LOC'): -0.672149,
#  ('word:天', 'B-ORG'): 0.589339,
#  ('word:天', 'I-ORG'): -0.02838,
#  ('word:天', 'B-PER'): -1.093443,
#  ('word:天', 'I-PER'): 0.090735,
#  ('-1:word:今', 'O'): 0.844257,
#  ('-1:word:今', 'B-LOC'): 0.018708,
#  ('-1:word:今', 'B-ORG'): -1.40343,
#  ('-1:word:今', 'I-ORG'): 0.374302,
#  ('-1:word:今', 'B-PER'): -0.00573,
#  ('-1:word:今', 'I-PER'): -0.80178,
#  ('+1:word:有', 'O'): -0.00036,
#  ('+1:word:有', 'B-LOC'): -0.692626,
#  ('+1:word:有', 'I-LOC'): 0.738747,
#  ('+1:word:有', 'B-ORG'): -0.317926,
#  ('+1:word:有', 'I-ORG'): 0.044573,
#  ('+1:word:有', 'B-PER'): 0.806352,
#  ('+1:word:有', 'I-PER'): -0.030275,
#  ('+2:word:收', 'O'): 0.013351,
#  ('+2:word:收', 'B-LOC'): -1.64841,
#  ('+2:word:收', 'I-LOC'): -0.023519,
#  ('+2:word:收', 'B-ORG'): -0.493211,
#  ('+2:word:收', 'I-ORG'): 0.359154,
#  ('+2:word:收', 'B-PER'): -1.166453,
#  ('+2:word:收', 'I-PER'): -0.526642,
#  ('word:有', 'O'): 3.434971,
#  ('word:有', 'B-ORG'): -0.775717,
#  ('word:有', 'I-ORG'): -0.053753,
#  ('word:有', 'I-PER'): 1.96204,
#  ('-1:word:天', 'O'): -1.403329,
#  ('-1:word:天', 'B-LOC'): -1.119004,
#  ('-1:word:天', 'I-LOC'): 1.758176,
#  ('-1:word:天', 'B-ORG'): -0.844737,
#  ('-1:word:天', 'I-ORG'): 0.266718,
#  ('-1:word:天', 'B-PER'): 0.008484,
#  ('-1:word:天', 'I-PER'): 0.798876,
#  ('-2:word:今', 'O'): -0.572048,
#  ('-2:word:今', 'B-LOC'): 0.189676,
#  ('-2:word:今', 'I-LOC'): 0.163623,
#  ('-2:word:今', 'B-ORG'): 0.580197,
#  ('-2:word:今', 'I-ORG'): 0.018367,
#  ('-2:word:今', 'B-PER'): -0.502742,
#  ('-2:word:今', 'I-PER'): 0.63154,
#  ('+1:word:收', 'O'): -0.605949,
#  ('+1:word:收', 'I-LOC'): 1.444785,
#  ('+1:word:收', 'I-ORG'): 0.60879,
#  ('+1:word:收', 'B-PER'): 0.705501,
#  ('+1:word:收', 'I-PER'): 0.290918,
#  ('+2:word:藏', 'O'): -0.136603,
#  ('+2:word:藏', 'B-LOC'): 0.011998,
#  ('+2:word:藏', 'I-LOC'): 0.3422,
#  ('+2:word:藏', 'B-ORG'): -2.755812,
#  ('+2:word:藏', 'I-ORG'): -0.143828,
#  ('+2:word:藏', 'B-PER'): -1.284594,
#  ('+2:word:藏', 'I-PER'): 1.15271,
#  ('word:收', 'O'): 3.235503,
#  ('word:收', 'B-ORG'): 6e-06,
#  ('word:收', 'I-ORG'): 0.486416,
#  ('-1:word:有', 'O'): -0.961337,
#  ('-1:word:有', 'B-LOC'): -0.090767,
#  ('-1:word:有', 'I-LOC'): -1.393493,
#  ('-1:word:有', 'B-ORG'): 0.062456,
#  ('-1:word:有', 'I-ORG'): 0.005711,
#  ('-1:word:有', 'B-PER'): 0.398752,
#  ('-1:word:有', 'I-PER'): 0.981637,
#  ('-2:word:天', 'O'): -0.233161,
#  ('-2:word:天', 'B-LOC'): 0.387041,
#  ('-2:word:天', 'I-LOC'): -0.02886,
#  ('-2:word:天', 'B-ORG'): 0.290161,
#  ('-2:word:天', 'I-ORG'): 0.036939,
#  ('-2:word:天', 'B-PER'): -0.040758,
#  ('-2:word:天', 'I-PER'): -2.296523,
#  ('+1:word:藏', 'O'): -0.76553,
#  ('+1:word:藏', 'B-LOC'): 2.309089,
#  ('+1:word:藏', 'I-LOC'): -1.24937,
#  ('+1:word:藏', 'B-ORG'): 1.386911,
#  ('+1:word:藏', 'I-ORG'): -0.455714,
#  ('+1:word:藏', 'I-PER'): -0.292305,
#  ('+2:word:价', 'O'): 0.688024,
#  ('+2:word:价', 'I-LOC'): -0.025087,
#  ('+2:word:价', 'B-ORG'): 1.182707,
#  ('+2:word:价', 'I-ORG'): 0.609748,
#  ('+2:word:价', 'I-PER'): -0.670036,
#  ('word:藏', 'O'): -3.080974,
#  ('word:藏', 'B-LOC'): 4.251617,
#  ('word:藏', 'I-LOC'): 0.615379,
#  ('word:藏', 'B-ORG'): 1.680738,
#  ('word:藏', 'I-ORG'): 0.019513,
#  ('word:藏', 'I-PER'): -1.477847,
#  ('-1:word:收', 'O'): 1.151194,
#  ('-1:word:收', 'B-LOC'): -0.365313,
#  ('-1:word:收', 'I-ORG'): 1.932675,
#  ('-2:word:有', 'O'): -0.114701,
#  ('-2:word:有', 'B-LOC'): -0.397986,
#  ('-2:word:有', 'I-LOC'): 0.530936,
#  ('-2:word:有', 'B-ORG'): -0.670943,
#  ('-2:word:有', 'I-ORG'): 0.177056,
#  ('-2:word:有', 'B-PER'): -1.007123,
#  ('-2:word:有', 'I-PER'): -0.306674,
#  ('+1:word:价', 'O'): 1.380791,
#  ('+1:word:价', 'B-ORG'): 1.337867,
#  ('+1:word:价', 'I-ORG'): 0.041665,
#  ('+2:word:值', 'O'): 1.08508,
#  ('+2:word:值', 'B-LOC'): 0.757696,
#  ('+2:word:值', 'I-LOC'): 2e-06,
#  ('+2:word:值', 'I-ORG'): -0.013289,
#  ('+2:word:值', 'I-PER'): -0.40586,
#  ('word:价', 'O'): 1.446062,
#  ('word:价', 'I-ORG'): 1.119366,
#  ('-1:word:藏', 'O'): 1.048269,
#  ('-1:word:藏', 'B-LOC'): -0.874106,
#  ('-1:word:藏', 'I-LOC'): -2.65003,
#  ('-1:word:藏', 'I-ORG'): 1.402529,
#  ('-2:word:收', 'O'): -0.408184,
#  ('-2:word:收', 'B-LOC'): -0.351964,
#  ('-2:word:收', 'I-LOC'): 1.343488,
#  ('-2:word:收', 'B-ORG'): -0.001743,
#  ('-2:word:收', 'I-ORG'): 0.422291,
#  ('-2:word:收', 'B-PER'): -0.111839,
#  ('+1:word:值', 'O'): 0.574572,
#  ('+1:word:值', 'I-LOC'): 0.689344,
#  ('+1:word:值', 'I-ORG'): 0.037063,
#  ('word:值', 'O'): 2.141022,
#  ('word:值', 'I-ORG'): 0.696336,
#  ('-1:word:价', 'O'): -0.028531,
#  ('-1:word:价', 'B-LOC'): 1.482592,
#  ('-1:word:价', 'B-ORG'): -0.267581,
#  ('-1:word:价', 'I-ORG'): 1.318591,
#  ('-2:word:藏', 'O'): 0.256721,
#  ('-2:word:藏', 'B-LOC'): -0.372191,
#  ('-2:word:藏', 'I-LOC'): 1.86634,
#  ('-2:word:藏', 'B-ORG'): -0.254809,
#  ('-2:word:藏', 'I-ORG'): -1.144528,
#  ('-2:word:藏', 'B-PER'): 1.089333,
#  ('+2:word:书', 'O'): -0.668696,
#  ('+2:word:书', 'B-LOC'): -2.684784,
#  ('+2:word:书', 'I-LOC'): -0.053129,
#  ('+2:word:书', 'B-ORG'): -0.130008,
#  ('+2:word:书', 'I-ORG'): 0.257813,
#  ('+2:word:书', 'B-PER'): 1.604798,
#  ('+2:word:书', 'I-PER'): -0.048834,
#  ('-1:word:值', 'O'): -0.024837,
#  ('-1:word:值', 'B-LOC'): 0.267883,
#  ('-1:word:值', 'B-ORG'): 0.600521,
#  ('-1:word:值', 'I-ORG'): -0.008056,
#  ('-1:word:值', 'B-PER'): -0.329548,
#  ('-2:word:价', 'O'): 0.327512,
#  ('-2:word:价', 'B-LOC'): -0.131017,
#  ('-2:word:价', 'B-ORG'): 1.008921,
#  ('-2:word:价', 'I-ORG'): -0.092334,
#  ('-2:word:价', 'B-PER'): -0.246537,
#  ('+1:word:书', 'O'): 0.021625,
#  ('+1:word:书', 'B-LOC'): -4.796719,
#  ('+1:word:书', 'I-LOC'): 0.123689,
#  ('+1:word:书', 'B-ORG'): -0.053061,
#  ('+1:word:书', 'I-ORG'): -0.012201,
#  ('+1:word:书', 'B-PER'): 1.591017,
#  ('+1:word:书', 'I-PER'): -1.056472,
#  ('+2:word:你', 'O'): -0.561833,
#  ('+2:word:你', 'B-LOC'): 0.085192,
#  ('+2:word:你', 'I-LOC'): -0.832997,
#  ('+2:word:你', 'I-ORG'): -1.22863,
#  ('+2:word:你', 'B-PER'): 2.136783,
#  ('+2:word:你', 'I-PER'): 1.175823,
#  ('word:书', 'O'): 0.431311,
#  ('word:书', 'B-LOC'): -2.293707,
#  ('word:书', 'I-LOC'): 0.608007,
#  ('word:书', 'B-ORG'): 0.042619,
#  ('word:书', 'I-ORG'): -1.534213,
#  ('word:书', 'I-PER'): -0.032486,
#  ('-2:word:值', 'O'): -0.013677,
#  ('-2:word:值', 'I-LOC'): 0.5979,
#  ('-2:word:值', 'B-ORG'): -0.195703,
#  ('-2:word:值', 'I-ORG'): 0.424084,
#  ('-2:word:值', 'B-PER'): -0.354429,
#  ('-2:word:值', 'I-PER'): -0.204892,
#  ('+1:word:你', 'O'): -0.216886,
#  ('+1:word:你', 'I-LOC'): 1.516464,
#  ('+1:word:你', 'I-PER'): 0.002353,
#  ('+2:word:没', 'O'): 0.019617,
#  ('+2:word:没', 'B-LOC'): -1.073626,
#  ('+2:word:没', 'I-LOC'): -0.95847,
#  ('+2:word:没', 'B-ORG'): 0.159906,
#  ('+2:word:没', 'I-ORG'): 0.29274,
#  ('+2:word:没', 'B-PER'): 0.143853,
#  ('+2:word:没', 'I-PER'): -0.251268,
#  ('word:你', 'O'): 2.005867,
#  ('word:你', 'I-LOC'): 1.951452,
#  ('-1:word:书', 'O'): -0.803638,
#  ('-1:word:书', 'B-LOC'): -2.381377,
#  ('-1:word:书', 'I-LOC'): 1.433889,
#  ('-1:word:书', 'B-ORG'): -0.625792,
#  ('-1:word:书', 'I-ORG'): 0.217716,
#  ('-1:word:书', 'B-PER'): 0.044405,
#  ('-1:word:书', 'I-PER'): -1.251462,
#  ('+1:word:没', 'O'): -1.108652,
#  ...}

# %% [markdown]
# ### 评测
# 虽然数据集中标签O比较多，但是我们更关注其它标签。因此下面计算标签O以外的其它标签的平均F1值。
# sklearn-crfsuite.metrics 提供了相应了功能。

# %%
labels = list(crf.classes_)
labels.remove('O')
labels
# Out:
# ['B-LOC', 'I-LOC', 'B-ORG', 'I-ORG', 'B-PER', 'I-PER']

# %%
y_pred = crf.predict(X_test)
metrics.flat_f1_score(y_test, y_pred, average='weighted', labels=labels)
# Out:
# 0.8362230945945955

# %%
# group B and I results
sorted_labels = sorted(
    labels, 
    key=lambda name: (name[1:], name[0])
)
print(metrics.flat_classification_report(
    y_test, y_pred, labels=sorted_labels, digits=3
))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass labels=['B-LOC', 'I-LOC', 'B-ORG', 'I-ORG', 'B-PER', 'I-PER'] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
#               precision    recall  f1-score   support
#
#        B-LOC      0.907     0.840     0.872      2877
#        I-LOC      0.882     0.827     0.854      4394
#        B-ORG      0.775     0.719     0.746      1331
#        I-ORG      0.805     0.784     0.794      5670
#        B-PER      0.932     0.770     0.843      1973
#        I-PER      0.890     0.867     0.878      3851
#
#    micro avg      0.862     0.812     0.836     20096
#    macro avg      0.865     0.801     0.831     20096
# weighted avg      0.864     0.812     0.836     20096

# %% [markdown]
# ELI5是一个Python包，可以检查sklearn_crfsuite.CRF模型的权重。
#
# 安装：pip install eli5

# %%
# !pip install eli5
# Out:
# Collecting eli5
#   Downloading eli5-0.11.0-py2.py3-none-any.whl (106 kB)
# Requirement already satisfied: attrs>16.0.0 in d:\anaconda3\lib\site-packages (from eli5) (20.3.0)
# Requirement already satisfied: scipy in c:\users\陈继延\appdata\roaming\python\python37\site-packages (from eli5) (1.2.1)
# Requirement already satisfied: graphviz in d:\anaconda3\lib\site-packages (from eli5) (0.16)
# Requirement already satisfied: jinja2 in c:\users\陈继延\appdata\roaming\python\python37\site-packages (from eli5) (2.11.3)
# Requirement already satisfied: numpy>=1.9.0 in c:\users\陈继延\appdata\roaming\python\python37\site-packages (from eli5) (1.19.5)
# Requirement already satisfied: tabulate>=0.7.7 in d:\anaconda3\lib\site-packages (from eli5) (0.8.9)
# Requirement already satisfied: six in c:\users\陈继延\appdata\roaming\python\python37\site-packages (from eli5) (1.15.0)
# Requirement already satisfied: scikit-learn>=0.20 in c:\users\陈继延\appdata\roaming\python\python37\site-packages (from eli5) (0.24.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\陈继延\appdata\roaming\python\python37\site-packages (from scikit-learn>=0.20->eli5) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in d:\anaconda3\lib\site-packages (from scikit-learn>=0.20->eli5) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\陈继延\appdata\roaming\python\python37\site-packages (from jinja2->eli5) (1.1.1)
# Installing collected packages: eli5
# Successfully installed eli5-0.11.0

# %%
import eli5
eli5.show_weights(crf,top = 20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-85a12945ce6e> in <module>()
#       1 import eli5
# ----> 2 eli5.show_weights(crf,top = 20)
#
# NameError: name 'crf' is not defined

# %% [markdown]
# 为便于阅读，我们只检查一部分标签。

# %%
eli5.show_weights(crf,top = 10,targets = ['O','B-LOC','B-ORG'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:209: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   warnings.warn('From version 0.24, get_params will raise an '
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
# <table class="eli5-transition-features" style="margin-bottom: 0.5em;">
#     <thead>
#         <tr>
#             <td>From \ To</td>
#
#                 <th>O</th>
#
#                 <th>B-LOC</th>
#
#                 <th>B-ORG</th>
#
#         </tr>
#     </thead>
#     <tbody>
#
#
#                 <tr>
#                     <th>O</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 86.34%)" title="O &rArr; O">
#                             3.771
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 98.32%)" title="O &rArr; B-LOC">
#                             0.188
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 97.36%)" title="O &rArr; B-ORG">
#                             -0.36
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>B-LOC</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 93.56%)" title="B-LOC &rArr; O">
#                             -1.288
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 93.59%)" title="B-LOC &rArr; B-LOC">
#                             -1.279
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 80.00%)" title="B-LOC &rArr; B-ORG">
#                             -6.498
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>B-ORG</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 87.61%)" title="B-ORG &rArr; O">
#                             -3.279
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 82.93%)" title="B-ORG &rArr; B-LOC">
#                             -5.182
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 89.91%)" title="B-ORG &rArr; B-ORG">
#                             -2.446
#                         </td>
#
#                 </tr>
#
#
#     </tbody>
# </table>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=O
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=B-LOC
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=B-ORG
#
# </b>
#
# top features
#                     </td>
#
#             </tr>
#             <tr>
#
#
#                         <td style="padding: 0px; border: 1px solid black; vertical-align: top;">
#
#
#
#
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; width: 100%;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +9.722
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word:、
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.23%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +9.559
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word:，
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.42%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +7.435
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word:在
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.69%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +7.263
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word:到
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.88%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +7.142
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word:是
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.11%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +7.001
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word:等
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.31%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.875
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word:某
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.63%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.674
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word:从
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 84.63%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 8528 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 84.43%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 5779 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 84.43%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -6.797
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word:澳
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 83.10%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -7.644
#     </td>
#     <td style="padding: 0 0.5em 0 0
